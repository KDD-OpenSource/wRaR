# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import csrar
from sklearn.model_selection import train_test_split

# %%
a = [-0.0301193837409, 0.000457581561074, 0.0242727083637, -0.0595909790806, 0.0288904326627,
     0.00644182319611,0.0023434551013, -0.0286107235616,0.0077272104507, 0.00737929719405]
np.mean(a)
# Out:
# -0.0040808577853465996

# %%
a = [np.array([1,2,3])]
for lol in a:
    print(lol)
# Out:
# [1 2 3]

# %%
def gini(array):
    array = array.flatten()
    if np.amin(array) < 0:
        array -= np.amin(array)
    array += 0.0000001
    array = np.sort(array)
    index = np.arange(1,array.shape[0]+1)
    n = array.shape[0]
    return ((np.sum((2 * index - n  - 1) * array)) / (n * np.sum(array)))

# %%
dist = np.array([1/4] * 4)
while gini(dist) < 0.6:
    dist = np.random.rand(4)
dist
# Out:
# array([ 0.85196203,  0.24442307,  0.00105643,  0.01633102])

# %%
binary_div_df = pd.DataFrame(columns=['0.0', '1.0', '2.0'], index=[0]).fillna(0)
binary_div_df2 = pd.DataFrame(columns=['0.0', '1.0', '2.0'], index=[0]).fillna(0.5)
test = {
    'a': binary_div_df,
    'b': binary_div_df2
}

# %%
for i in binary_div_df['0.0'].iteritems():
    print(i.column)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-122-7eae7d2f8226> in <module>()
#       1 for i in binary_div_df['0.0'].iteritems():
# ----> 2     print(i.column)
#
# AttributeError: 'tuple' object has no attribute 'column'

# %%
a, _ = ('2', '3')
_
# Out:
# '3'

# %%
indices = [tuple(index) for index in test]
scores = [score for index, score in test.items()]
new_relevancies = pd.DataFrame(data=scores, index=indices)
new_relevancies
# Out:
#                                       0
# (a,)     0.0  1.0  2.0
# 0    0    0    0
# (b,)     0.0  1.0  2.0
# 0  0.5  0.5  0.5

# %%
new_relevancies[0][('a',)]
# Out:
#    0.0  1.0  2.0
# 0    0    0    0

# %%
dist
# Out:
# array([ 0.76493359,  0.21945511,  0.00094851,  0.01466279])

# %%
data = pd.read_csv('../data/Injector_Median100k.csv')

# %%
X = data.drop('Col174', axis=1)
y = data['Col174']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=5)

# %%
X_test
# Out:
#              0         1         2         3         4         5         6   \
# 24166 -1.132954 -0.529332 -2.280111  0.828081 -1.266780 -2.409994  2.445317
# 42699  0.051053  1.057167 -0.445697  0.660821 -0.321692  0.822010 -0.306635
# 15927  0.300304  1.235321  0.109885  1.854542  0.583341  2.236067 -1.667990
# 7473  -0.835659  0.541545  2.082648  0.381698 -0.454977  1.997699 -2.174094
# 5070  -1.527724  1.769555  0.576986 -0.824658  0.708849  1.047867 -0.525502
# 33926 -0.656407 -2.976683  0.280318 -0.019446 -1.501808 -2.157457  1.035022
# 21409 -0.379643  0.513969 -0.921569 -2.130628  0.874219 -1.385711  1.458493
# 9495   0.168654  0.343844 -0.108644 -1.875611  1.744207 -0.708428  0.838252
# 16235  0.934957  0.372184 -0.168887  0.923648 -0.624599  0.976759 -0.616142
# 35747 -0.217729  0.634640  0.487273  0.200610 -1.182167  0.576834 -0.693506
# 46288  2.072761  0.665912  1.139228 -0.406565 -1.354836  0.972402 -1.566761
# 13560 -1.077186  0.143189  1.405300  0.538192  1.524841  1.622361 -1.295567
# 29644  0.629522  1.430145  0.161626 -0.181094  0.495560  1.009825 -0.622896
# 29761 -0.503010  1.185166 -0.851120  0.670070  1.284460  0.183297
# 3702  -1.275804  2.742860  0.377494  1.050098 -1.135627  0.061285
# ...         ...       ...       ...       ...       ...       ...
# 6776  -1.952684  0.307649 -0.143970 -0.281238  0.382520 -1.865187
# 45778 -1.989663  1.649454 -1.186804  0.050202  0.561386 -1.650623
# 48938 -0.020463  1.278007 -0.094947  1.230205  0.436598  0.674549
# 32893  1.351401  1.215244 -0.564244  0.475683 -0.556636  1.766536
# 41205 -0.164819  1.348283  0.531658  0.935262 -0.156223  1.130905
# 35316 -1.300072  1.389524  0.018404  1.801680  0.601440 -0.794375
# 23517 -0.127399  0.298638  0.992542  0.529484 -0.988055 -0.574835
# 30555 -1.665895  2.135505 -0.758306  0.287203  0.839659  0.203200
# 42846 -0.003041 -0.340101 -0.331936 -0.409241  0.109809 -0.331814
# 12294 -1.005828  0.038186 -1.444750 -1.837764  1.276758  0.409136
# 6515  -0.487693  1.324108 -2.224128 -1.160872  1.695148  1.003631
# 28951  0.224112 -0.169206  0.169785 -0.005447  0.863462  0.953998
# 33175 -0.978358 -0.673559  0.854962  0.054490 -0.781271 -1.704267
# 28608  0.700495 -0.721574  1.857552 -0.230633 -3.008021 -0.339836
# 25327  1.507716  0.442539  0.499775  0.100771 -1.370300  1.860553
# 10943  0.095487  0.638561 -0.947495 -0.464360  0.174937  0.272635
# 6269  -1.398410  1.897622  1.931589  2.181372 -1.078357 -0.025764
# 24099 -0.832680  0.868470  0.163343  0.405714 -0.963914 -1.003570
# 23394  0.738360 -1.031238  0.078042 -0.152660  0.069883  0.129116
# 37500 -0.782231  1.846556  1.507638  2.391030 -0.158651  1.022274
# 42612  0.533545  0.794478  0.760739  0.785960 -1.903092  0.285121
# 37296  0.458829  1.300335  0.033884  0.390097 -0.245630  0.699059
# 3462   1.213059 -0.936463  0.502258 -1.060963 -1.464393  0.542699
# 43207 -1.043853 -0.755893 -2.803276 -2.657247  1.736235 -1.238861
# 47134 -1.270209  2.908065 -1.049802 -0.136266  0.156257  0.689491
# 32224  0.794752 -0.931022  0.714915 -0.043012 -0.591377  0.531827
# 48978 -0.008783  0.060061 -2.189978 -1.530259  1.859496  0.770780
# 27462  1.316415 -2.535784  0.128263 -1.072084 -0.414392 -0.207324
# 38221 -1.312032  3.021636 -1.838702  0.514814  2.081245  1.219208
# 25437 -0.395022  0.065984 -0.455296 -0.361563  0.884739  0.123973
#
# [20000 rows x 13 columns]

# %%
rar_data = pd.concat([X_train, y_train], axis=1)

# %%
data2 = pd.DataFrame(data=np.arange(len(rar_data)), index=rar_data.index)

# %%
len(rar_data)
# Out:
# 60123

# %%
target = 'Col174'
rar = csrar.rar.RaR(rar_data)

# %%
rar.run(target, k=5, runs=200)

# %%
from sklearn.ensemble import ExtraTreesClassifier
clf = ExtraTreesClassifier()
clf.fit(data.drop('Col174', axis=1), data['Col174'])

# %%
ranking = []
for index, importance in enumerate(clf.feature_importances_):
    ranking.append((data.columns[index], importance))
ranking.sort(key=lambda r: r[1], reverse=True)
for (index, rank) in enumerate(ranking):
        print('{}. {} with a score of {}'.format(index + 1, rank[0], rank[1]))
